# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
from datetime import date
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as LinReg
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
import math
import plotly.graph_objects as go
import plotly.express as px

# %%
plt.rcParams["figure.figsize"] = (16,9) # Ashas tip! This makes plots bigger!!!!
sns.set_style("ticks")
sns.set_theme(style="white", palette='Paired')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
fifa = pd.read_csv('fifa.csv')
fifa
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
columns = ['OVA','Crossing','Finishing','Heading Accuracy','Short Passing','Volleys','Dribbling','Curve','FK Accuracy','Long Passing','Ball Control','Acceleration','Sprint Speed','Agility','Reactions','Balance','Shot Power','Jumping','Stamina','Strength','Long Shots','Aggression','Interceptions','Positioning','Vision','Penalties','Composure','Defending','Marking','Standing Tackle','Sliding Tackle','GK Diving','GK Handling','GK Kicking','GK Positioning','GK Reflexes','Base Stats']
players = fifa[columns]

# %%
players = players.dropna()

# %%
players
# Out:
#        OVA  Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  \
# 0       64        54         47                43             70     44.0
# 1       77        66         79                76             68     76.0
# 2       80        73         76                34             78     75.0
# 3       59        44         42                58             62     36.0
# 4       65        49         37                61             68     34.0
# ...    ...       ...        ...               ...            ...      ...
# 11695   65        36         72                65             57     60.0
# 11696   65        62         24                51             59     28.0
# 11697   70        12         14                13             29     16.0
# 11698   67        64         66                51             64     41.0
# 11700   64        43         64                65             64     53.0
#
#        Dribbling  Curve  FK Accuracy  Long Passing  Ball Control  \
# ...

# %%
y = players['OVA']
X = players.drop('OVA', axis=1)

# %%
transf_mms = MinMaxScaler().fit(X)
X_nor = transf_mms.transform(X)
print(X_nor.shape)
X_num_minmax = pd.DataFrame(X_nor, columns=X.columns)
X = X_num_minmax
# Out:
# (11422, 36)

# %%
X_train, X_test, y_train, y_test=tts(X, y, test_size=.2, random_state =5)

# %%
linreg=LinReg()    # model
linreg.fit(X_train, y_train)   # model training
y_pred_linreg=linreg.predict(X_test)   # model prediction

# %%
lm = linear_model.LinearRegression()

# %%
lm.fit(X,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# 103293906841.1164
# [ 1.59640394e+00 -2.29408754e+00  6.11406320e+00  5.18954278e+00
#  -7.23334496e-01 -2.45159179e+00 -5.10199541e-01  7.40195927e-02
#  -3.37244090e+00  1.17003567e+01 -1.38240238e+00 -2.72211781e+00
#  -9.32450743e-01  2.03820913e+01 -1.20841830e+00 -7.83814092e-02
#  -6.80034135e-01 -8.50252132e-01 -1.16114591e+00 -4.06812591e+00
#  -1.80987592e+00 -2.22572739e+00 -5.68289027e+00 -4.53996726e+00
#   1.49747983e-01  8.11332459e+00  5.10271900e+12 -1.83863154e+12
#  -1.73533763e+12 -1.73533763e+12 -7.94284971e-01 -4.39897241e-01
#  -2.23710302e+00  8.10227939e-01 -7.12966308e-01  3.02987334e+01]

# %%
pred = lm.predict(X_test)
pred
# Out:
# array([58.06478882, 63.67404175, 72.52339172, ..., 61.15675354,
#        70.90130615, 64.28704834])

# %%
train_r2 = linreg.score(X_train, y_train)
test_r2 = linreg.score(X_test, y_test)
print (f'Train R2: {train_r2} \nTest R2: {test_r2}')
# Out:
# Train R2: 0.8924168089180701
# Test R2: 0.8888244817734245

# %%
train_mse=mse(linreg.predict(X_train), y_train)
test_mse=mse(linreg.predict(X_test), y_test)
print(f'Train MSE: {train_mse} \nTest MSE: {test_mse}')
# Out:
# Train MSE: 5.02566332079179
# Test MSE: 5.267734822575451

# %%
test_rmse = np.sqrt(test_mse)
print(f'RMSE: {test_rmse}')
# Out:
# RMSE: 2.29515464023134

# %%
fifa_val = pd.read_csv('fifa21_validate.csv')

# %%
columns = ['OVA','Crossing','Finishing','Heading Accuracy','Short Passing','Volleys','Dribbling','Curve','FK Accuracy','Long Passing','Ball Control','Acceleration','Sprint Speed','Agility','Reactions','Balance','Shot Power','Jumping','Stamina','Strength','Long Shots','Aggression','Interceptions','Positioning','Vision','Penalties','Composure','Defending','Marking','Standing Tackle','Sliding Tackle','GK Diving','GK Handling','GK Kicking','GK Positioning','GK Reflexes','Base Stats']
fifa_v = fifa_val[columns]

# %%
fifa_v = players.dropna()

# %%
y2 = fifa_v['OVA'] #target, y lowercase
X2 = fifa_v.drop('OVA', axis=1) #features, X uppercase

# %%
X_nor = transf_mms.transform(X2)
print(X_nor.shape)
X2 = pd.DataFrame(X_nor, columns=X2.columns)
# Out:
# (11422, 36)

# %%
validation_predictions = lm.predict(X2)
validation_predictions
# Out:
# array([65.05761719, 76.22789001, 75.22787476, ..., 71.14024353,
#        64.891922  , 63.54393005])

# %%
validations_mse = mse(validation_predictions, y2)

# %%
print(validations_mse)
# Out:
# 5.0692969325723505

# %%
rmse = np.sqrt(validations_mse)
rmse
# Out:
# 2.251509922823426
